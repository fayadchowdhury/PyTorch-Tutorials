# %% [markdown]
# ### Creating a training pipeline in PyTorch

# %% [markdown]
# Typically the training pipeline has 3 steps:
# <ul>
#     <li>Design the model - figure out the input size, the output size and the forward pass</li>
#     <li>Construct the loss function</li>
#     <li>Construct the training loop - forward pass, loss, backward pass, update parameters</li>
# </ul>

# %%
import torch
import torch.nn as nn # Import the Neural Network module

# Assume the same linear regression model
# y = Wx + b = 2x + 3

# # Inputs
# X = torch.tensor([1, 2, 3, 4], dtype=torch.float32)

# # Outputs
# Y = torch.tensor([5, 7, 9, 11], dtype=torch.float32)

# For nn.Linear, the inputs and outputs are declared differently
# Number of rows = number of samples
# Number of columns = number of features
# Inputs
X = torch.tensor([[1],
                 [2],
                 [3],
                 [4],], dtype=torch.float32)

# Outputs
Y = torch.tensor([[5],
                 [7],
                 [9],
                 [11]], dtype=torch.float32)

# We need the number of samples and the number of features
# This is easily obtained from X or the input (rows and columns respectively)
num_samples, num_features = X.shape

# We also need the number of outputs
# This is easily obtained from Y or the output (columns)
num_outputs = Y.shape[1]

# We do not need the weights and biases
# These are handled by the nn.Linear() function
# # Weights and biases
# # We need to calculate the gradient of the loss function with respect
# # to the weights and biases. So we need to add the requires_grad=True
# # flag to the tensors
# W = torch.tensor(0, dtype=torch.float32, requires_grad=True) # Assume that we start with 0 weight initially and there is only one input dimension
# b = torch.tensor(0, dtype=torch.float32, requires_grad=True) # Assume that we start with 0 bias initially

# We do not need this
# This will be handled by the nn.Linear() function
# # Predict
# def forward(W, X, b):
#     return W*X+b
model = nn.Linear(num_features, num_outputs)

# We do not need this
# This will be handled by the nn.MSELoss() function
# # Loss
# # Assume we are going with L = MSE
# def loss(Y, Yhat):
#     return ((Yhat - Y)**2).mean()
loss = nn.MSELoss()

# We do not need this
# This will be handled by the autograd library in PyTorch
# # Gradient - dL
# def gradient(X, Y, Yhat):
#     dW = np.dot(-2*X, Y-Yhat).mean()
#     db = -2*((Y-Yhat)).mean()
#     return dW, db

# We also need an optimiser
# This will be done using the torch.optim.SGD() function
alpha = 0.1
# optimiser = torch.optim.SGD([W, b], lr=alpha) # This is used when the weights and biases are manually defined
optimiser = torch.optim.SGD(model.parameters(), lr=alpha)

# %%
# Training
epochs = 100 # Converges at alpha = 0.1

for epoch in range(epochs):
    print("Epoch " + str(epoch+1))
    # Forward pass
    # Yhat = forward(W, X, b)
    Yhat = model(X)
    print("Prediction: " + str(Yhat))
    # Loss prediction
    prediction_loss = loss(Y, Yhat)
    print("Loss: " + str(prediction_loss))
    # Backward pass
    # dW, db = gradient(X, Y, Yhat)
    prediction_loss.backward()
    # Update weights and biases
    # with torch.no_grad():
    #     W -= alpha * W.grad
    #     b -= alpha * b.grad
    optimiser.step()
    # Zero out the gradients
    # W.grad.zero_()
    # b.grad.zero_()
    optimiser.zero_grad()
# Out:
# Epoch 1
# Prediction: tensor([[1.3361],
#         [1.7311],
#         [2.1261],
#         [2.5211]], grad_fn=<AddmmBackward0>)
# Loss: tensor(40.0817, grad_fn=<MseLossBackward0>)
# Epoch 2
# Prediction: tensor([[ 5.9874],
#         [ 9.8193],
#         [13.6512],
#         [17.4831]], grad_fn=<AddmmBackward0>)
# Loss: tensor(18.1471, grad_fn=<MseLossBackward0>)
# Epoch 3
# Prediction: tensor([[2.9147],
#         [4.4210],
#         [5.9273],
#         [7.4337]], grad_fn=<AddmmBackward0>)
# Loss: tensor(8.2899, grad_fn=<MseLossBackward0>)
# Epoch 4
# Prediction: tensor([[ 5.0162],
#         [ 8.0588],
#         [11.1015],
#         [14.1441]], grad_fn=<AddmmBackward0>)
# Loss: tensor(3.8558, grad_fn=<MseLossBackward0>)
# Epoch 5
# Prediction: tensor([[3.6494],
#         [5.6413],
#         [7.6332],
#         [9.6251]], grad_fn=<AddmmBackward0>)
# Loss: tensor(1.8571, grad_fn=<MseLossBackward0>)
# Epoch 6
# Prediction: tensor([[ 4.6054],
#         [ 7.2806],
#         [ 9.9559],
#         [12.6312]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.9523, grad_fn=<MseLossBackward0>)
# Epoch 7
# Prediction: tensor([[ 4.0037],
#         [ 6.2010],
#         [ 8.3984],
#         [10.5957]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.5391, grad_fn=<MseLossBackward0>)
# Epoch 8
# Prediction: tensor([[ 4.4446],
#         [ 6.9427],
#         [ 9.4409],
#         [11.9390]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.3470, grad_fn=<MseLossBackward0>)
# Epoch 9
# Prediction: tensor([[ 4.1858],
#         [ 6.4635],
#         [ 8.7412],
#         [11.0189]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.2545, grad_fn=<MseLossBackward0>)
# Epoch 10
# Prediction: tensor([[ 4.3947],
#         [ 6.8018],
#         [ 9.2089],
#         [11.6160]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.2072, grad_fn=<MseLossBackward0>)
# Epoch 11
# Prediction: tensor([[ 4.2892],
#         [ 6.5918],
#         [ 8.8945],
#         [11.1971]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1805, grad_fn=<MseLossBackward0>)
# Epoch 12
# Prediction: tensor([[ 4.3933],
#         [ 6.7487],
#         [ 9.1041],
#         [11.4595]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1633, grad_fn=<MseLossBackward0>)
# Epoch 13
# Prediction: tensor([[ 4.3560],
#         [ 6.6593],
#         [ 8.9626],
#         [11.2660]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1507, grad_fn=<MseLossBackward0>)
# Epoch 14
# Prediction: tensor([[ 4.4125],
#         [ 6.7345],
#         [ 9.0565],
#         [11.3785]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1405, grad_fn=<MseLossBackward0>)
# Epoch 15
# Prediction: tensor([[ 4.4051],
#         [ 6.6989],
#         [ 8.9927],
#         [11.2864]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1317, grad_fn=<MseLossBackward0>)
# Epoch 16
# Prediction: tensor([[ 4.4396],
#         [ 6.7371],
#         [ 9.0345],
#         [11.3320]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1236, grad_fn=<MseLossBackward0>)
# Epoch 17
# Prediction: tensor([[ 4.4452],
#         [ 6.7254],
#         [ 9.0056],
#         [11.2858]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1162, grad_fn=<MseLossBackward0>)
# Epoch 18
# Prediction: tensor([[ 4.4693],
#         [ 6.7467],
#         [ 9.0241],
#         [11.3015]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1093, grad_fn=<MseLossBackward0>)
# Epoch 19
# Prediction: tensor([[ 4.4802],
#         [ 6.7455],
#         [ 9.0109],
#         [11.2762]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.1028, grad_fn=<MseLossBackward0>)
# Epoch 20
# Prediction: tensor([[ 4.4991],
#         [ 6.7590],
#         [ 9.0189],
#         [11.2788]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0968, grad_fn=<MseLossBackward0>)
# Epoch 21
# Prediction: tensor([[ 4.5119],
#         [ 6.7623],
#         [ 9.0127],
#         [11.2632]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0911, grad_fn=<MseLossBackward0>)
# Epoch 22
# Prediction: tensor([[ 4.5280],
#         [ 6.7721],
#         [ 9.0161],
#         [11.2602]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0857, grad_fn=<MseLossBackward0>)
# Epoch 23
# Prediction: tensor([[ 4.5411],
#         [ 6.7771],
#         [ 9.0131],
#         [11.2491]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0806, grad_fn=<MseLossBackward0>)
# Epoch 24
# Prediction: tensor([[ 4.5555],
#         [ 6.7850],
#         [ 9.0144],
#         [11.2439]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0759, grad_fn=<MseLossBackward0>)
# Epoch 25
# Prediction: tensor([[ 4.5684],
#         [ 6.7906],
#         [ 9.0129],
#         [11.2351]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0714, grad_fn=<MseLossBackward0>)
# Epoch 26
# Prediction: tensor([[ 4.5816],
#         [ 6.7974],
#         [ 9.0132],
#         [11.2290]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0672, grad_fn=<MseLossBackward0>)
# Epoch 27
# Prediction: tensor([[ 4.5939],
#         [ 6.8031],
#         [ 9.0123],
#         [11.2215]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0632, grad_fn=<MseLossBackward0>)
# Epoch 28
# Prediction: tensor([[ 4.6062],
#         [ 6.8093],
#         [ 9.0123],
#         [11.2153]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0595, grad_fn=<MseLossBackward0>)
# Epoch 29
# Prediction: tensor([[ 4.6179],
#         [ 6.8148],
#         [ 9.0117],
#         [11.2086]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0560, grad_fn=<MseLossBackward0>)
# Epoch 30
# Prediction: tensor([[ 4.6294],
#         [ 6.8205],
#         [ 9.0115],
#         [11.2025]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0527, grad_fn=<MseLossBackward0>)
# Epoch 31
# Prediction: tensor([[ 4.6405],
#         [ 6.8258],
#         [ 9.0111],
#         [11.1963]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0496, grad_fn=<MseLossBackward0>)
# Epoch 32
# Prediction: tensor([[ 4.6513],
#         [ 6.8310],
#         [ 9.0108],
#         [11.1906]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0467, grad_fn=<MseLossBackward0>)
# Epoch 33
# Prediction: tensor([[ 4.6617],
#         [ 6.8361],
#         [ 9.0104],
#         [11.1848]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0439, grad_fn=<MseLossBackward0>)
# Epoch 34
# Prediction: tensor([[ 4.6718],
#         [ 6.8410],
#         [ 9.0101],
#         [11.1793]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0413, grad_fn=<MseLossBackward0>)
# Epoch 35
# Prediction: tensor([[ 4.6816],
#         [ 6.8457],
#         [ 9.0098],
#         [11.1739]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0389, grad_fn=<MseLossBackward0>)
# Epoch 36
# Prediction: tensor([[ 4.6912],
#         [ 6.8504],
#         [ 9.0095],
#         [11.1687]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0366, grad_fn=<MseLossBackward0>)
# Epoch 37
# Prediction: tensor([[ 4.7004],
#         [ 6.8548],
#         [ 9.0092],
#         [11.1637]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0344, grad_fn=<MseLossBackward0>)
# Epoch 38
# Prediction: tensor([[ 4.7094],
#         [ 6.8592],
#         [ 9.0090],
#         [11.1588]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0324, grad_fn=<MseLossBackward0>)
# Epoch 39
# Prediction: tensor([[ 4.7181],
#         [ 6.8634],
#         [ 9.0087],
#         [11.1540]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0305, grad_fn=<MseLossBackward0>)
# Epoch 40
# Prediction: tensor([[ 4.7265],
#         [ 6.8675],
#         [ 9.0084],
#         [11.1494]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0287, grad_fn=<MseLossBackward0>)
# Epoch 41
# Prediction: tensor([[ 4.7347],
#         [ 6.8715],
#         [ 9.0082],
#         [11.1449]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0270, grad_fn=<MseLossBackward0>)
# Epoch 42
# Prediction: tensor([[ 4.7427],
#         [ 6.8753],
#         [ 9.0079],
#         [11.1406]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0254, grad_fn=<MseLossBackward0>)
# Epoch 43
# Prediction: tensor([[ 4.7504],
#         [ 6.8790],
#         [ 9.0077],
#         [11.1364]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0239, grad_fn=<MseLossBackward0>)
# Epoch 44
# Prediction: tensor([[ 4.7578],
#         [ 6.8827],
#         [ 9.0075],
#         [11.1323]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0225, grad_fn=<MseLossBackward0>)
# Epoch 45
# Prediction: tensor([[ 4.7651],
#         [ 6.8862],
#         [ 9.0072],
#         [11.1283]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0212, grad_fn=<MseLossBackward0>)
# Epoch 46
# Prediction: tensor([[ 4.7721],
#         [ 6.8896],
#         [ 9.0070],
#         [11.1245]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0199, grad_fn=<MseLossBackward0>)
# Epoch 47
# Prediction: tensor([[ 4.7789],
#         [ 6.8929],
#         [ 9.0068],
#         [11.1208]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0187, grad_fn=<MseLossBackward0>)
# Epoch 48
# Prediction: tensor([[ 4.7856],
#         [ 6.8961],
#         [ 9.0066],
#         [11.1171]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0176, grad_fn=<MseLossBackward0>)
# Epoch 49
# Prediction: tensor([[ 4.7920],
#         [ 6.8992],
#         [ 9.0064],
#         [11.1136]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0166, grad_fn=<MseLossBackward0>)
# Epoch 50
# Prediction: tensor([[ 4.7982],
#         [ 6.9022],
#         [ 9.0062],
#         [11.1102]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0156, grad_fn=<MseLossBackward0>)
# Epoch 51
# Prediction: tensor([[ 4.8043],
#         [ 6.9051],
#         [ 9.0060],
#         [11.1069]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0147, grad_fn=<MseLossBackward0>)
# Epoch 52
# Prediction: tensor([[ 4.8101],
#         [ 6.9080],
#         [ 9.0059],
#         [11.1037]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0138, grad_fn=<MseLossBackward0>)
# Epoch 53
# Prediction: tensor([[ 4.8158],
#         [ 6.9107],
#         [ 9.0057],
#         [11.1006]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0130, grad_fn=<MseLossBackward0>)
# Epoch 54
# Prediction: tensor([[ 4.8213],
#         [ 6.9134],
#         [ 9.0055],
#         [11.0976]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0122, grad_fn=<MseLossBackward0>)
# Epoch 55
# Prediction: tensor([[ 4.8267],
#         [ 6.9160],
#         [ 9.0053],
#         [11.0947]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0115, grad_fn=<MseLossBackward0>)
# Epoch 56
# Prediction: tensor([[ 4.8319],
#         [ 6.9185],
#         [ 9.0052],
#         [11.0919]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0108, grad_fn=<MseLossBackward0>)
# Epoch 57
# Prediction: tensor([[ 4.8369],
#         [ 6.9210],
#         [ 9.0050],
#         [11.0891]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0102, grad_fn=<MseLossBackward0>)
# Epoch 58
# Prediction: tensor([[ 4.8418],
#         [ 6.9233],
#         [ 9.0049],
#         [11.0864]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0096, grad_fn=<MseLossBackward0>)
# Epoch 59
# Prediction: tensor([[ 4.8465],
#         [ 6.9256],
#         [ 9.0047],
#         [11.0839]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0090, grad_fn=<MseLossBackward0>)
# Epoch 60
# Prediction: tensor([[ 4.8511],
#         [ 6.9278],
#         [ 9.0046],
#         [11.0813]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0085, grad_fn=<MseLossBackward0>)
# Epoch 61
# Prediction: tensor([[ 4.8556],
#         [ 6.9300],
#         [ 9.0045],
#         [11.0789]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0080, grad_fn=<MseLossBackward0>)
# Epoch 62
# Prediction: tensor([[ 4.8599],
#         [ 6.9321],
#         [ 9.0043],
#         [11.0765]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0075, grad_fn=<MseLossBackward0>)
# Epoch 63
# Prediction: tensor([[ 4.8641],
#         [ 6.9341],
#         [ 9.0042],
#         [11.0743]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0071, grad_fn=<MseLossBackward0>)
# Epoch 64
# Prediction: tensor([[ 4.8681],
#         [ 6.9361],
#         [ 9.0041],
#         [11.0720]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0067, grad_fn=<MseLossBackward0>)
# Epoch 65
# Prediction: tensor([[ 4.8721],
#         [ 6.9380],
#         [ 9.0039],
#         [11.0699]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0063, grad_fn=<MseLossBackward0>)
# Epoch 66
# Prediction: tensor([[ 4.8759],
#         [ 6.9399],
#         [ 9.0038],
#         [11.0678]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0059, grad_fn=<MseLossBackward0>)
# Epoch 67
# Prediction: tensor([[ 4.8796],
#         [ 6.9417],
#         [ 9.0037],
#         [11.0658]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0056, grad_fn=<MseLossBackward0>)
# Epoch 68
# Prediction: tensor([[ 4.8832],
#         [ 6.9434],
#         [ 9.0036],
#         [11.0638]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0052, grad_fn=<MseLossBackward0>)
# Epoch 69
# Prediction: tensor([[ 4.8867],
#         [ 6.9451],
#         [ 9.0035],
#         [11.0619]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0049, grad_fn=<MseLossBackward0>)
# Epoch 70
# Prediction: tensor([[ 4.8901],
#         [ 6.9468],
#         [ 9.0034],
#         [11.0600]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0046, grad_fn=<MseLossBackward0>)
# Epoch 71
# Prediction: tensor([[ 4.8934],
#         [ 6.9484],
#         [ 9.0033],
#         [11.0582]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0044, grad_fn=<MseLossBackward0>)
# Epoch 72
# Prediction: tensor([[ 4.8966],
#         [ 6.9499],
#         [ 9.0032],
#         [11.0565]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0041, grad_fn=<MseLossBackward0>)
# Epoch 73
# Prediction: tensor([[ 4.8997],
#         [ 6.9514],
#         [ 9.0031],
#         [11.0548]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0039, grad_fn=<MseLossBackward0>)
# Epoch 74
# Prediction: tensor([[ 4.9027],
#         [ 6.9529],
#         [ 9.0030],
#         [11.0532]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0036, grad_fn=<MseLossBackward0>)
# Epoch 75
# Prediction: tensor([[ 4.9056],
#         [ 6.9543],
#         [ 9.0029],
#         [11.0516]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0034, grad_fn=<MseLossBackward0>)
# Epoch 76
# Prediction: tensor([[ 4.9084],
#         [ 6.9556],
#         [ 9.0028],
#         [11.0500]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0032, grad_fn=<MseLossBackward0>)
# Epoch 77
# Prediction: tensor([[ 4.9112],
#         [ 6.9570],
#         [ 9.0027],
#         [11.0485]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0030, grad_fn=<MseLossBackward0>)
# Epoch 78
# Prediction: tensor([[ 4.9138],
#         [ 6.9583],
#         [ 9.0027],
#         [11.0471]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0028, grad_fn=<MseLossBackward0>)
# Epoch 79
# Prediction: tensor([[ 4.9164],
#         [ 6.9595],
#         [ 9.0026],
#         [11.0457]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0027, grad_fn=<MseLossBackward0>)
# Epoch 80
# Prediction: tensor([[ 4.9189],
#         [ 6.9607],
#         [ 9.0025],
#         [11.0443]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0025, grad_fn=<MseLossBackward0>)
# Epoch 81
# Prediction: tensor([[ 4.9214],
#         [ 6.9619],
#         [ 9.0024],
#         [11.0430]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0024, grad_fn=<MseLossBackward0>)
# Epoch 82
# Prediction: tensor([[ 4.9237],
#         [ 6.9630],
#         [ 9.0024],
#         [11.0417]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0022, grad_fn=<MseLossBackward0>)
# Epoch 83
# Prediction: tensor([[ 4.9260],
#         [ 6.9641],
#         [ 9.0023],
#         [11.0404]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0021, grad_fn=<MseLossBackward0>)
# Epoch 84
# Prediction: tensor([[ 4.9282],
#         [ 6.9652],
#         [ 9.0022],
#         [11.0392]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0020, grad_fn=<MseLossBackward0>)
# Epoch 85
# Prediction: tensor([[ 4.9304],
#         [ 6.9663],
#         [ 9.0021],
#         [11.0380]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0019, grad_fn=<MseLossBackward0>)
# Epoch 86
# Prediction: tensor([[ 4.9324],
#         [ 6.9673],
#         [ 9.0021],
#         [11.0369]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0018, grad_fn=<MseLossBackward0>)
# Epoch 87
# Prediction: tensor([[ 4.9345],
#         [ 6.9682],
#         [ 9.0020],
#         [11.0358]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch 88
# Prediction: tensor([[ 4.9364],
#         [ 6.9692],
#         [ 9.0020],
#         [11.0347]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0016, grad_fn=<MseLossBackward0>)
# Epoch 89
# Prediction: tensor([[ 4.9383],
#         [ 6.9701],
#         [ 9.0019],
#         [11.0337]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0015, grad_fn=<MseLossBackward0>)
# Epoch 90
# Prediction: tensor([[ 4.9402],
#         [ 6.9710],
#         [ 9.0018],
#         [11.0327]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0014, grad_fn=<MseLossBackward0>)
# Epoch 91
# Prediction: tensor([[ 4.9420],
#         [ 6.9719],
#         [ 9.0018],
#         [11.0317]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0013, grad_fn=<MseLossBackward0>)
# Epoch 92
# Prediction: tensor([[ 4.9437],
#         [ 6.9727],
#         [ 9.0017],
#         [11.0308]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0012, grad_fn=<MseLossBackward0>)
# Epoch 93
# Prediction: tensor([[ 4.9454],
#         [ 6.9735],
#         [ 9.0017],
#         [11.0298]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0011, grad_fn=<MseLossBackward0>)
# Epoch 94
# Prediction: tensor([[ 4.9470],
#         [ 6.9743],
#         [ 9.0016],
#         [11.0289]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0011, grad_fn=<MseLossBackward0>)
# Epoch 95
# Prediction: tensor([[ 4.9486],
#         [ 6.9751],
#         [ 9.0016],
#         [11.0281]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch 96
# Prediction: tensor([[ 4.9502],
#         [ 6.9758],
#         [ 9.0015],
#         [11.0272]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0010, grad_fn=<MseLossBackward0>)
# Epoch 97
# Prediction: tensor([[ 4.9516],
#         [ 6.9766],
#         [ 9.0015],
#         [11.0264]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0009, grad_fn=<MseLossBackward0>)
# Epoch 98
# Prediction: tensor([[ 4.9531],
#         [ 6.9773],
#         [ 9.0014],
#         [11.0256]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch 99
# Prediction: tensor([[ 4.9545],
#         [ 6.9780],
#         [ 9.0014],
#         [11.0249]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0008, grad_fn=<MseLossBackward0>)
# Epoch 100
# Prediction: tensor([[ 4.9559],
#         [ 6.9786],
#         [ 9.0014],
#         [11.0241]], grad_fn=<AddmmBackward0>)
# Loss: tensor(0.0007, grad_fn=<MseLossBackward0>)

# %% [markdown]
# It is also possible to implement a custom model by:
# <ul>
#     <li>Creating a class inheriting the nn.Module class</li>
#     <li>Overriding the __init__() and forward() methods</li>
#     <ul>
#         <li>The __init__() function will usually have the input and output sizes specified and call the super method. Next it will define the model itself or the layers of the model.</li>
#         <li>The forward() function will return the prediction</li>
#     </ul>
# </ul>

# %%
class LinearRegression(nn.Module): # This class inherits the nn.Module class
    def __init__(self, input_size, output_size): # Needs to override the __init__
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(input_size, output_size)
        
    def forward(self, x): # Also needs to override the forward() forward pass
        return self.linear(x)

# %%
model = LinearRegression(num_features, num_outputs)
optimiser = torch.optim.SGD(model.parameters(), lr=alpha)

# Very simplified training loop
for epoch in range(epochs):
    print("Epoch " + str(epoch+1))
    prediction = model(X)
    prediction_loss = loss(prediction, Y)
    prediction_loss.backward()
    optimiser.step()
    optimiser.zero_grad()
    print(f"Prediction = {prediction}, Loss = {prediction_loss.item():.3f}")
# Out:
# Epoch 1
# Prediction = tensor([[-1.3155],
#         [-2.1327],
#         [-2.9498],
#         [-3.7670]], grad_fn=<AddmmBackward0>), Loss = 121.039
# Epoch 2
# Prediction = tensor([[ 6.7677],
#         [11.9254],
#         [17.0832],
#         [22.2409]], grad_fn=<AddmmBackward0>), Loss = 54.770
# Epoch 3
# Prediction = tensor([[1.4252],
#         [2.5414],
#         [3.6576],
#         [4.7737]], grad_fn=<AddmmBackward0>), Loss = 24.992
# Epoch 4
# Prediction = tensor([[ 5.0766],
#         [ 8.8639],
#         [12.6513],
#         [16.4387]], grad_fn=<AddmmBackward0>), Loss = 11.598
# Epoch 5
# Prediction = tensor([[2.6994],
#         [4.6611],
#         [6.6228],
#         [8.5845]], grad_fn=<AddmmBackward0>), Loss = 5.562
# Epoch 6
# Prediction = tensor([[ 4.3596],
#         [ 7.5099],
#         [10.6602],
#         [13.8105]], grad_fn=<AddmmBackward0>), Loss = 2.831
# Epoch 7
# Prediction = tensor([[ 3.3125],
#         [ 5.6327],
#         [ 7.9529],
#         [10.2731]], grad_fn=<AddmmBackward0>), Loss = 1.586
# Epoch 8
# Prediction = tensor([[ 4.0775],
#         [ 6.9212],
#         [ 9.7650],
#         [12.6088]], grad_fn=<AddmmBackward0>), Loss = 1.008
# Epoch 9
# Prediction = tensor([[ 3.6263],
#         [ 6.0876],
#         [ 8.5489],
#         [11.0101]], grad_fn=<AddmmBackward0>), Loss = 0.731
# Epoch 10
# Prediction = tensor([[ 3.9882],
#         [ 6.6751],
#         [ 9.3619],
#         [12.0487]], grad_fn=<AddmmBackward0>), Loss = 0.590
# Epoch 11
# Prediction = tensor([[ 3.8036],
#         [ 6.3095],
#         [ 8.8153],
#         [11.3212]], grad_fn=<AddmmBackward0>), Loss = 0.511
# Epoch 12
# Prediction = tensor([[ 3.9834],
#         [ 6.5816],
#         [ 9.1798],
#         [11.7781]], grad_fn=<AddmmBackward0>), Loss = 0.462
# Epoch 13
# Prediction = tensor([[ 3.9174],
#         [ 6.4256],
#         [ 8.9339],
#         [11.4422]], grad_fn=<AddmmBackward0>), Loss = 0.425
# Epoch 14
# Prediction = tensor([[ 4.0144],
#         [ 6.5558],
#         [ 9.0971],
#         [11.6384]], grad_fn=<AddmmBackward0>), Loss = 0.396
# Epoch 15
# Prediction = tensor([[ 4.0006],
#         [ 6.4934],
#         [ 8.9862],
#         [11.4790]], grad_fn=<AddmmBackward0>), Loss = 0.371
# Epoch 16
# Prediction = tensor([[ 4.0596],
#         [ 6.5593],
#         [ 9.0590],
#         [11.5586]], grad_fn=<AddmmBackward0>), Loss = 0.349
# Epoch 17
# Prediction = tensor([[ 4.0683],
#         [ 6.5385],
#         [ 9.0087],
#         [11.4789]], grad_fn=<AddmmBackward0>), Loss = 0.328
# Epoch 18
# Prediction = tensor([[ 4.1092],
#         [ 6.5751],
#         [ 9.0409],
#         [11.5068]], grad_fn=<AddmmBackward0>), Loss = 0.308
# Epoch 19
# Prediction = tensor([[ 4.1271],
#         [ 6.5725],
#         [ 9.0179],
#         [11.4633]], grad_fn=<AddmmBackward0>), Loss = 0.290
# Epoch 20
# Prediction = tensor([[ 4.1591],
#         [ 6.5956],
#         [ 9.0320],
#         [11.4684]], grad_fn=<AddmmBackward0>), Loss = 0.273
# Epoch 21
# Prediction = tensor([[ 4.1804],
#         [ 6.6008],
#         [ 9.0213],
#         [11.4417]], grad_fn=<AddmmBackward0>), Loss = 0.257
# Epoch 22
# Prediction = tensor([[ 4.2075],
#         [ 6.6174],
#         [ 9.0272],
#         [11.4370]], grad_fn=<AddmmBackward0>), Loss = 0.242
# Epoch 23
# Prediction = tensor([[ 4.2295],
#         [ 6.6257],
#         [ 9.0220],
#         [11.4182]], grad_fn=<AddmmBackward0>), Loss = 0.227
# Epoch 24
# Prediction = tensor([[ 4.2538],
#         [ 6.6390],
#         [ 9.0242],
#         [11.4095]], grad_fn=<AddmmBackward0>), Loss = 0.214
# Epoch 25
# Prediction = tensor([[ 4.2753],
#         [ 6.6484],
#         [ 9.0216],
#         [11.3947]], grad_fn=<AddmmBackward0>), Loss = 0.201
# Epoch 26
# Prediction = tensor([[ 4.2975],
#         [ 6.6599],
#         [ 9.0222],
#         [11.3846]], grad_fn=<AddmmBackward0>), Loss = 0.189
# Epoch 27
# Prediction = tensor([[ 4.3182],
#         [ 6.6694],
#         [ 9.0207],
#         [11.3719]], grad_fn=<AddmmBackward0>), Loss = 0.178
# Epoch 28
# Prediction = tensor([[ 4.3389],
#         [ 6.6798],
#         [ 9.0206],
#         [11.3615]], grad_fn=<AddmmBackward0>), Loss = 0.168
# Epoch 29
# Prediction = tensor([[ 4.3585],
#         [ 6.6891],
#         [ 9.0196],
#         [11.3502]], grad_fn=<AddmmBackward0>), Loss = 0.158
# Epoch 30
# Prediction = tensor([[ 4.3778],
#         [ 6.6986],
#         [ 9.0193],
#         [11.3401]], grad_fn=<AddmmBackward0>), Loss = 0.149
# Epoch 31
# Prediction = tensor([[ 4.3964],
#         [ 6.7075],
#         [ 9.0186],
#         [11.3297]], grad_fn=<AddmmBackward0>), Loss = 0.140
# Epoch 32
# Prediction = tensor([[ 4.4145],
#         [ 6.7163],
#         [ 9.0181],
#         [11.3199]], grad_fn=<AddmmBackward0>), Loss = 0.132
# Epoch 33
# Prediction = tensor([[ 4.4320],
#         [ 6.7247],
#         [ 9.0175],
#         [11.3103]], grad_fn=<AddmmBackward0>), Loss = 0.124
# Epoch 34
# Prediction = tensor([[ 4.4490],
#         [ 6.7330],
#         [ 9.0170],
#         [11.3010]], grad_fn=<AddmmBackward0>), Loss = 0.116
# Epoch 35
# Prediction = tensor([[ 4.4655],
#         [ 6.7410],
#         [ 9.0165],
#         [11.2920]], grad_fn=<AddmmBackward0>), Loss = 0.110
# Epoch 36
# Prediction = tensor([[ 4.4815],
#         [ 6.7488],
#         [ 9.0160],
#         [11.2833]], grad_fn=<AddmmBackward0>), Loss = 0.103
# Epoch 37
# Prediction = tensor([[ 4.4970],
#         [ 6.7563],
#         [ 9.0155],
#         [11.2748]], grad_fn=<AddmmBackward0>), Loss = 0.097
# Epoch 38
# Prediction = tensor([[ 4.5121],
#         [ 6.7636],
#         [ 9.0151],
#         [11.2666]], grad_fn=<AddmmBackward0>), Loss = 0.091
# Epoch 39
# Prediction = tensor([[ 4.5267],
#         [ 6.7706],
#         [ 9.0146],
#         [11.2586]], grad_fn=<AddmmBackward0>), Loss = 0.086
# Epoch 40
# Prediction = tensor([[ 4.5409],
#         [ 6.7775],
#         [ 9.0142],
#         [11.2508]], grad_fn=<AddmmBackward0>), Loss = 0.081
# Epoch 41
# Prediction = tensor([[ 4.5546],
#         [ 6.7842],
#         [ 9.0137],
#         [11.2433]], grad_fn=<AddmmBackward0>), Loss = 0.076
# Epoch 42
# Prediction = tensor([[ 4.5679],
#         [ 6.7906],
#         [ 9.0133],
#         [11.2360]], grad_fn=<AddmmBackward0>), Loss = 0.072
# Epoch 43
# Prediction = tensor([[ 4.5809],
#         [ 6.7969],
#         [ 9.0129],
#         [11.2290]], grad_fn=<AddmmBackward0>), Loss = 0.067
# Epoch 44
# Prediction = tensor([[ 4.5934],
#         [ 6.8030],
#         [ 9.0125],
#         [11.2221]], grad_fn=<AddmmBackward0>), Loss = 0.063
# Epoch 45
# Prediction = tensor([[ 4.6056],
#         [ 6.8089],
#         [ 9.0122],
#         [11.2155]], grad_fn=<AddmmBackward0>), Loss = 0.060
# Epoch 46
# Prediction = tensor([[ 4.6174],
#         [ 6.8146],
#         [ 9.0118],
#         [11.2090]], grad_fn=<AddmmBackward0>), Loss = 0.056
# Epoch 47
# Prediction = tensor([[ 4.6289],
#         [ 6.8202],
#         [ 9.0115],
#         [11.2028]], grad_fn=<AddmmBackward0>), Loss = 0.053
# Epoch 48
# Prediction = tensor([[ 4.6400],
#         [ 6.8255],
#         [ 9.0111],
#         [11.1967]], grad_fn=<AddmmBackward0>), Loss = 0.050
# Epoch 49
# Prediction = tensor([[ 4.6508],
#         [ 6.8308],
#         [ 9.0108],
#         [11.1908]], grad_fn=<AddmmBackward0>), Loss = 0.047
# Epoch 50
# Prediction = tensor([[ 4.6612],
#         [ 6.8358],
#         [ 9.0105],
#         [11.1851]], grad_fn=<AddmmBackward0>), Loss = 0.044
# Epoch 51
# Prediction = tensor([[ 4.6713],
#         [ 6.8407],
#         [ 9.0101],
#         [11.1795]], grad_fn=<AddmmBackward0>), Loss = 0.041
# Epoch 52
# Prediction = tensor([[ 4.6812],
#         [ 6.8455],
#         [ 9.0098],
#         [11.1742]], grad_fn=<AddmmBackward0>), Loss = 0.039
# Epoch 53
# Prediction = tensor([[ 4.6907],
#         [ 6.8501],
#         [ 9.0095],
#         [11.1690]], grad_fn=<AddmmBackward0>), Loss = 0.037
# Epoch 54
# Prediction = tensor([[ 4.7000],
#         [ 6.8546],
#         [ 9.0093],
#         [11.1639]], grad_fn=<AddmmBackward0>), Loss = 0.035
# Epoch 55
# Prediction = tensor([[ 4.7090],
#         [ 6.8590],
#         [ 9.0090],
#         [11.1590]], grad_fn=<AddmmBackward0>), Loss = 0.032
# Epoch 56
# Prediction = tensor([[ 4.7177],
#         [ 6.8632],
#         [ 9.0087],
#         [11.1542]], grad_fn=<AddmmBackward0>), Loss = 0.031
# Epoch 57
# Prediction = tensor([[ 4.7261],
#         [ 6.8673],
#         [ 9.0085],
#         [11.1496]], grad_fn=<AddmmBackward0>), Loss = 0.029
# Epoch 58
# Prediction = tensor([[ 4.7343],
#         [ 6.8713],
#         [ 9.0082],
#         [11.1451]], grad_fn=<AddmmBackward0>), Loss = 0.027
# Epoch 59
# Prediction = tensor([[ 4.7423],
#         [ 6.8751],
#         [ 9.0080],
#         [11.1408]], grad_fn=<AddmmBackward0>), Loss = 0.025
# Epoch 60
# Prediction = tensor([[ 4.7500],
#         [ 6.8789],
#         [ 9.0077],
#         [11.1366]], grad_fn=<AddmmBackward0>), Loss = 0.024
# Epoch 61
# Prediction = tensor([[ 4.7575],
#         [ 6.8825],
#         [ 9.0075],
#         [11.1325]], grad_fn=<AddmmBackward0>), Loss = 0.023
# Epoch 62
# Prediction = tensor([[ 4.7648],
#         [ 6.8860],
#         [ 9.0073],
#         [11.1285]], grad_fn=<AddmmBackward0>), Loss = 0.021
# Epoch 63
# Prediction = tensor([[ 4.7718],
#         [ 6.8894],
#         [ 9.0070],
#         [11.1247]], grad_fn=<AddmmBackward0>), Loss = 0.020
# Epoch 64
# Prediction = tensor([[ 4.7786],
#         [ 6.8927],
#         [ 9.0068],
#         [11.1209]], grad_fn=<AddmmBackward0>), Loss = 0.019
# Epoch 65
# Prediction = tensor([[ 4.7853],
#         [ 6.8959],
#         [ 9.0066],
#         [11.1173]], grad_fn=<AddmmBackward0>), Loss = 0.018
# Epoch 66
# Prediction = tensor([[ 4.7917],
#         [ 6.8991],
#         [ 9.0064],
#         [11.1138]], grad_fn=<AddmmBackward0>), Loss = 0.017
# Epoch 67
# Prediction = tensor([[ 4.7979],
#         [ 6.9021],
#         [ 9.0062],
#         [11.1104]], grad_fn=<AddmmBackward0>), Loss = 0.016
# Epoch 68
# Prediction = tensor([[ 4.8040],
#         [ 6.9050],
#         [ 9.0061],
#         [11.1071]], grad_fn=<AddmmBackward0>), Loss = 0.015
# Epoch 69
# Prediction = tensor([[ 4.8098],
#         [ 6.9079],
#         [ 9.0059],
#         [11.1039]], grad_fn=<AddmmBackward0>), Loss = 0.014
# Epoch 70
# Prediction = tensor([[ 4.8155],
#         [ 6.9106],
#         [ 9.0057],
#         [11.1008]], grad_fn=<AddmmBackward0>), Loss = 0.013
# Epoch 71
# Prediction = tensor([[ 4.8211],
#         [ 6.9133],
#         [ 9.0055],
#         [11.0978]], grad_fn=<AddmmBackward0>), Loss = 0.012
# Epoch 72
# Prediction = tensor([[ 4.8264],
#         [ 6.9159],
#         [ 9.0054],
#         [11.0948]], grad_fn=<AddmmBackward0>), Loss = 0.012
# Epoch 73
# Prediction = tensor([[ 4.8316],
#         [ 6.9184],
#         [ 9.0052],
#         [11.0920]], grad_fn=<AddmmBackward0>), Loss = 0.011
# Epoch 74
# Prediction = tensor([[ 4.8367],
#         [ 6.9208],
#         [ 9.0050],
#         [11.0892]], grad_fn=<AddmmBackward0>), Loss = 0.010
# Epoch 75
# Prediction = tensor([[ 4.8415],
#         [ 6.9232],
#         [ 9.0049],
#         [11.0866]], grad_fn=<AddmmBackward0>), Loss = 0.010
# Epoch 76
# Prediction = tensor([[ 4.8463],
#         [ 6.9255],
#         [ 9.0047],
#         [11.0840]], grad_fn=<AddmmBackward0>), Loss = 0.009
# Epoch 77
# Prediction = tensor([[ 4.8509],
#         [ 6.9277],
#         [ 9.0046],
#         [11.0815]], grad_fn=<AddmmBackward0>), Loss = 0.009
# Epoch 78
# Prediction = tensor([[ 4.8554],
#         [ 6.9299],
#         [ 9.0045],
#         [11.0790]], grad_fn=<AddmmBackward0>), Loss = 0.008
# Epoch 79
# Prediction = tensor([[ 4.8597],
#         [ 6.9320],
#         [ 9.0043],
#         [11.0767]], grad_fn=<AddmmBackward0>), Loss = 0.008
# Epoch 80
# Prediction = tensor([[ 4.8639],
#         [ 6.9340],
#         [ 9.0042],
#         [11.0744]], grad_fn=<AddmmBackward0>), Loss = 0.007
# Epoch 81
# Prediction = tensor([[ 4.8680],
#         [ 6.9360],
#         [ 9.0041],
#         [11.0721]], grad_fn=<AddmmBackward0>), Loss = 0.007
# Epoch 82
# Prediction = tensor([[ 4.8719],
#         [ 6.9379],
#         [ 9.0040],
#         [11.0700]], grad_fn=<AddmmBackward0>), Loss = 0.006
# Epoch 83
# Prediction = tensor([[ 4.8757],
#         [ 6.9398],
#         [ 9.0038],
#         [11.0679]], grad_fn=<AddmmBackward0>), Loss = 0.006
# Epoch 84
# Prediction = tensor([[ 4.8795],
#         [ 6.9416],
#         [ 9.0037],
#         [11.0658]], grad_fn=<AddmmBackward0>), Loss = 0.006
# Epoch 85
# Prediction = tensor([[ 4.8831],
#         [ 6.9433],
#         [ 9.0036],
#         [11.0639]], grad_fn=<AddmmBackward0>), Loss = 0.005
# Epoch 86
# Prediction = tensor([[ 4.8866],
#         [ 6.9450],
#         [ 9.0035],
#         [11.0620]], grad_fn=<AddmmBackward0>), Loss = 0.005
# Epoch 87
# Prediction = tensor([[ 4.8900],
#         [ 6.9467],
#         [ 9.0034],
#         [11.0601]], grad_fn=<AddmmBackward0>), Loss = 0.005
# Epoch 88
# Prediction = tensor([[ 4.8933],
#         [ 6.9483],
#         [ 9.0033],
#         [11.0583]], grad_fn=<AddmmBackward0>), Loss = 0.004
# Epoch 89
# Prediction = tensor([[ 4.8965],
#         [ 6.9498],
#         [ 9.0032],
#         [11.0566]], grad_fn=<AddmmBackward0>), Loss = 0.004
# Epoch 90
# Prediction = tensor([[ 4.8996],
#         [ 6.9513],
#         [ 9.0031],
#         [11.0549]], grad_fn=<AddmmBackward0>), Loss = 0.004
# Epoch 91
# Prediction = tensor([[ 4.9026],
#         [ 6.9528],
#         [ 9.0030],
#         [11.0532]], grad_fn=<AddmmBackward0>), Loss = 0.004
# Epoch 92
# Prediction = tensor([[ 4.9055],
#         [ 6.9542],
#         [ 9.0029],
#         [11.0516]], grad_fn=<AddmmBackward0>), Loss = 0.003
# Epoch 93
# Prediction = tensor([[ 4.9083],
#         [ 6.9556],
#         [ 9.0028],
#         [11.0501]], grad_fn=<AddmmBackward0>), Loss = 0.003
# Epoch 94
# Prediction = tensor([[ 4.9111],
#         [ 6.9569],
#         [ 9.0027],
#         [11.0486]], grad_fn=<AddmmBackward0>), Loss = 0.003
# Epoch 95
# Prediction = tensor([[ 4.9137],
#         [ 6.9582],
#         [ 9.0027],
#         [11.0471]], grad_fn=<AddmmBackward0>), Loss = 0.003
# Epoch 96
# Prediction = tensor([[ 4.9163],
#         [ 6.9594],
#         [ 9.0026],
#         [11.0457]], grad_fn=<AddmmBackward0>), Loss = 0.003
# Epoch 97
# Prediction = tensor([[ 4.9188],
#         [ 6.9607],
#         [ 9.0025],
#         [11.0444]], grad_fn=<AddmmBackward0>), Loss = 0.003
# Epoch 98
# Prediction = tensor([[ 4.9212],
#         [ 6.9618],
#         [ 9.0024],
#         [11.0430]], grad_fn=<AddmmBackward0>), Loss = 0.002
# Epoch 99
# Prediction = tensor([[ 4.9236],
#         [ 6.9630],
#         [ 9.0024],
#         [11.0417]], grad_fn=<AddmmBackward0>), Loss = 0.002
# Epoch 100
# Prediction = tensor([[ 4.9259],
#         [ 6.9641],
#         [ 9.0023],
#         [11.0405]], grad_fn=<AddmmBackward0>), Loss = 0.002
